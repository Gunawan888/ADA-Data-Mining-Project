# %% [markdown]
# # House Price Regression

# %% [markdown]
# The process of building the regression model for the house price will be divided into 3 steps:
# 1. Visualization & Pre-processing
# 2. Model Building

# %% [markdown]
# -------------------------------------------------------------

# %% [markdown]
# # 1. Visualization & Pre-Processing

# %% [markdown]
# # 1A. Importing Libraries

# %%
#import some necessary libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn 
#ignore annoying warning (from sklearn and seaborn)

from scipy import stats
from scipy.stats import norm, skew #for some statistics

# %% [markdown]
# # 1B. Loading & Inspecting Data

# %%
#Now let's import and put the train and test datasets in  pandas dataframe
train = pd.read_csv("~/Desktop\House Pricing/train.csv")
test = pd.read_csv("~/Desktop\House Pricing/test.csv")

# %%
# Provide statictics on training set
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# Size of the 
print ("Size of train data : {}" .format(train.shape))
print ("Size of test data : {}" .format(test.shape))
# Out:
# Size of train data : (1460, 81)
# Size of test data : (1459, 80)

# %% [markdown]
# # 1C. Data Processing

# %% [markdown]
# ** A. Drop down ID as we don't need it in the predictive model **

# %%
#Save the 'Id' column
train_ID = train['Id']
test_ID = test['Id']

#Now drop the  'Id' colum since it's unnecessary for the prediction process.
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

# %% [markdown]
# -------------------------------------------------------------

# %% [markdown]
# ** B. Dealing with the outliers **
# > Outliear in the GrLivArea is recommended by the author of the data  to remove it. The author says in documentation     “I would recommend removing any houses with more than 4000 square feet from the data set (which eliminates these five unusual observations) before assigning it to students.”
#
# Reference:

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# ** Explanation: **
#
# In the figure, we can see some outliers with ** Low SalePrice ** and ** High GrLivArea**. This observations of house with this feature is unresonable as the price is usually getting more expensive as the GrArea get bigger. Therefore, we need to remove these outliers

# %%
# Removing the datapoints with 
# GrLivArea more than 4000 with salePrice less than 3000
train = train.drop(train[(train['GrLivArea']>4000) 
                         & 
                         (train['SalePrice']<300000)].index)

# %% [markdown]
# -------------------------------------------------

# %% [markdown]
# ** C. Correlation Analysis **

# %% [markdown]
# ** 1. Correlation Matrix **

# %%
# Find the most correlated attributes
corrmat = train.corr()
top_corr_var = corrmat.index[abs(corrmat["SalePrice"])>0.5]

# Plotting the correlation matrix
plt.figure(figsize=(10,10))
g = sns.heatmap(train[top_corr_var].corr(),
                annot=True,cmap="RdYlGn")

# %% [markdown]
# ** Explanation: **
# - From this we can tell which features **(OverallQual, GrLivArea and TotalBsmtSF )** are highly positively correlated with the SalePrice with 0.8,
# - **GarageCars and GarageArea ** also seems correlated with other, Since the no. of car that will fit into the garage will depend on GarageArea.

# %% [markdown]
# ** 2. Barplot between OverAllQual & SalePrice **

# %%
sns.barplot(train.OverallQual,train.SalePrice)

# %% [markdown]
# **3. Scatter plots between 'SalePrice' and correlated variables**

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(train[cols], size = 1.5)
plt.show();

# %% [markdown]
# ** Explanation: **
#
# One of the figures we may find interesting is the one between ** 'TotalBsmtSF' and 'GrLiveArea'. **
#
# We can see the dots drawing a linear line, which almost acts like a border. It totally makes sense that the majority of the dots stay below that line. Basement areas can be equal to the above ground living area, but it is not expected a basement area bigger than the above ground living area

# %%
sns.regplot(train.GrLivArea,train.TotalBsmtSF)

# %% [markdown]
# -----------------------------------------------------------

# %% [markdown]
# ** 4. Target Variable Transform **
#
#
# **Lets check the skewness of data**
# ![Skew](https://cdn-images-1.medium.com/max/800/1*hxVvqttoCSkUT2_R1zA0Tg.gif)

# %%
def check_skewness(col):
    sns.distplot(train[col] , fit=norm);
    fig = plt.figure()
    res = stats.probplot(train[col], plot=plt)
    # Get the fitted parameters used by the function
    (mu, sigma) = norm.fit(train[col])
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

# Check the skewness of target variable
check_skewness('SalePrice')
# Out:
#  mu = 180932.92 and sigma = 79467.79

# %% [markdown]
# **Explanation:**
#
# 1. The black curve is tend to be right-skewed
# 2. The distribution is positively skewed (Positive trend)
#
# **Solution:** Perform Log Tranform to reduce the skewness

# %%
#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
train["SalePrice"] = np.log1p(train["SalePrice"])

check_skewness('SalePrice')
# Out:
#  mu = 12.02 and sigma = 0.40

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# ###  Feature Engineering ###

# %% [markdown]
# Before feature engineering, we will oncatenate both training and testing set

# %%
# Store the size of training set and testing set for reassembling
ntrain = train.shape[0]
ntest = test.shape[0]

y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (2917, 79)

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ** 1. Handling Missing Data/Values **

# %%
# Calculate the missing value ratio for each attribute
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})

# %%
# Plotting the missing valuerati for each attributes
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5,1,'Percent missing data by feature')

# %% [markdown]
# * **"None"** means the nonexistent of the attribute in the potential house
#
#
# Ex: in 'Fence', None means the house has ** NO FENCE **

# %%
# Replacing missing values with the new values
mis_col = ["PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu", "MSSubClass"]
all_data[mis_col] = all_data[mis_col].fillna("None")

# %% [markdown]
# * **LotFrontage** : Since the area of each street connected to the house property most likely have a similar area to other houses in its neighborhood , we can fill in missing values by the median LotFrontage of the neighborhood.

# %%
# Grouping by Neighborhood and Check the LotFrontage. Most of the grouping has similar areas
grouped_df = all_data.groupby('Neighborhood')['LotFrontage']

for key, item in grouped_df:
    print(key,"\n")
    print(grouped_df.get_group(key))
    break
    
#Group by neighborhood and fill in missing value by the median LotFrontage of all the neighborhood
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))
# Out:
# Blmngtn
#
# 219     43.0
# 229     43.0
# 385     43.0
# 443     53.0
# 465      NaN
# 558      NaN
# 596     53.0
# 638     53.0
# 789     43.0
# 850      NaN
# 981     43.0
# 1003    43.0
# 1018    43.0
# 1022    43.0
# 1125    53.0
# 1392    53.0
# 1413    51.0
# 1481    43.0
# 1683    43.0
# 1982     NaN
# 1983     NaN
# 1984    53.0
# 2318     NaN
# 2319    53.0
# 2669    43.0
# 2670     NaN
# 2671     NaN
# 2672    43.0
# Name: LotFrontage, dtype: float64

# %% [markdown]
# * **GarageType, GarageFinish, GarageQual and GarageCond** : Replacing missing data with None as per documentation.

# %%
for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
    all_data[col] = all_data[col].fillna('None')

abc = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond','GarageYrBlt', 'GarageArea', 'GarageCars']
all_data.groupby('GarageType')[abc].count()
# Out:
#             GarageType  GarageFinish  GarageQual  GarageCond  GarageYrBlt  \
# GarageType
# 2Types              23            23          23          23           23
# Attchd            1722          1722        1722        1722         1722
# Basment             36            36          36          36           36
# BuiltIn            185           185         185         185          185
# CarPort             15            15          15          15           15
# Detchd             779           779         779         779          777
# None               157           157         157         157            0
#
#             GarageArea  GarageCars
# GarageType
# 2Types              23          23
# Attchd            1722        1722
# Basment             36          36
# BuiltIn            185         185
# CarPort             15          15
# Detchd             778         778
# None               157         157

# %% [markdown]
# * **GarageYrBlt, GarageArea and GarageCars** : Replacing missing data with 0 (Since No garage = no cars in such garage.)

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# * **BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath and BsmtHalfBath** : missing values are likely zero for having no basement

# %%
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# * **BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1 and BsmtFinType2** : For all these categorical basement-related features, NaN means that there is no basement.

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')

# %% [markdown]
# * **MasVnrArea and MasVnrType** : NA most likely means no masonry veneer for these houses. We can fill 0 for the area and None for the type.

# %%
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

# %% [markdown]
# * **MSZoning (The general zoning classification)** : 'RL' is by far the most common value. So we can fill in missing values with 'RL'

# %%
print(all_data['MSZoning'].value_counts())

# Replace missing value with most frequent values
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
# Out:
# RL         2263
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: MSZoning, dtype: int64

# %% [markdown]
# * **Utilities** : Since this is a categorical data and most of the data are of same category, Its not gonna effect on model. So we choose to drop it.

# %%
print(all_data['Utilities'].value_counts())

# Drop the variable for its low variance
all_data = all_data.drop(['Utilities'], axis=1)
# Out:
# AllPub    2914
# NoSeWa       1
# Name: Utilities, dtype: int64

# %% [markdown]
# * **Functional** : data description says NA means typical

# %%
all_data["Functional"] = all_data["Functional"].fillna("Typ")

# %% [markdown]
# * **Electrical,KitchenQual, Exterior1st, Exterior2nd, SaleType** : Since this all are categorical values so its better to replace nan values with the most used keyword.

# %%
mode_col = ['Electrical','KitchenQual', 'Exterior1st', 'Exterior2nd', 'SaleType']
for col in mode_col:
    all_data[col] = all_data[col].fillna(all_data[col].mode()[0])

# %% [markdown]
# --------------------------------------------

# %%
#Check remaining missing values if any 
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
print("There is no more missing values")
# Out:
# There is no more missing values

# %% [markdown]
# --------------------------------------------------

# %% [markdown]
# ** 2. Converting some numerical variables that are actually categorical.**
#
# As you can see the category range from 1 to 9 which are numerical (**not ordinal type**). Since its categorical we need to change it to String type.
#
# If we do not convert these to categorical, some model may get affect by this as model will compare the value 1<5<10 . We dont need that to happen with our model.

# %%
#MSSubClass=The building class
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)

#Changing OverallCond into a categorical variable
all_data['OverallCond'] = all_data['OverallCond'].astype(str)

#Year and month sold are transformed into categorical features.
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ** 3. Label Encoding / Category to Number**
#
# Ex: 'Country' attribute has France, USA, Canada => 0,1,2

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
# process columns, apply LabelEncoder to categorical features
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[c].values)) 
    all_data[c] = lbl.transform(list(all_data[c].values))

# shape        
print('Shape all_data: {}'.format(all_data.shape))
# Out:
# Shape all_data: (2917, 78)

# %% [markdown]
# ----------------------------

# %% [markdown]
# **4. Adding feature derived from existing attributes **

# %%
# Adding total square foor of the house
# Total area = the total area of basement + first and second floor areas of each house
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %% [markdown]
# ** 5. Variable skewness transformation **

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index
# Check the skew of all numerical features
skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(15)
# Out:
# Skew in numerical features:
#                     Skew
# MiscVal        21.939672
# PoolArea       17.688664
# LotArea        13.109495
# LowQualFinSF   12.084539
# 3SsnPorch      11.372080
# LandSlope       4.973254
# KitchenAbvGr    4.300550
# BsmtFinSF2      4.144503
# EnclosedPorch   4.002344
# ScreenPorch     3.945101
# BsmtHalfBath    3.929996
# MasVnrArea      2.621719
# OpenPorchSF     2.529358
# WoodDeckSF      1.844792
# 1stFlrSF        1.257286

# %%
# Tranform the numerical variables into smoother variance

skewness = skewness[abs(skewness) > 0.75]
print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))

from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    #all_data[feat] += 1
    all_data[feat] = boxcox1p(all_data[feat], lam)
# Out:
# There are 59 skewed numerical features to Box Cox transform

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ** 6. Making dummies variable for categorical variable **

# %%
all_data = pd.get_dummies(all_data)

# %% [markdown]
# ---------------------------------------

# %%
# Creating the pre-processed test and training set
print("This is the original shape of training set", train.shape)
print("This is the original shape of training set", test.shape)
train = all_data[:ntrain]
test = all_data[ntrain:]
print("This is the shape of training set", train.shape)
print("This is the shape of testing set", test.shape)
# Out:
# This is the original shape of training set (1458, 80)
# This is the original shape of training set (1459, 79)
# This is the shape of training set (1458, 220)
# This is the shape of testing set (1459, 220)

# %% [markdown]
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Steps:
#
# 1. Importing Libraries
#
# 2. We will use models
#  - Lasso
#  - Ridge
#  - ElasticNet
#  - Gradient Boosting
#
# 3. Find the Cross Validation Score.
# 4. Calculate the mean of all model's prediction.
# 5. Submit the CSV file.

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from xgboost import XGBRegressor

from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error

import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
# ** Validation Set : To Evaluate the model **

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %% [markdown]
# # 1. XGB REGRESSOR

# %%
xgb_model = XGBRegressor(n_estimators=3000, eta=0.04,
                        max_depth=4, colsample_bytree=0.7,
                        min_samples_leaf=15, min_samples_split=10, 
                        loss='huber', random_state =5)

# Evaluate the Regressor
score = rmsle_cv(xgb_model)
print("XGB score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %% [markdown]
# # 2. GBOOST REGRESSOR

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %% [markdown]
# # 3. Lasso Regression
# LASSO (Least Absolute Shrinkage Selector Operator), is quite similar to ridge.
#
# In case of lasso, even at smaller alpha’s, our coefficients are reducing to absolute zeroes.
#  Therefore, lasso selects the only some feature while reduces the coefficients of others to zero. This property is known as feature selection and which is absent in case of ridge.
#
# - Lasso uses L1 regularization technique.
# - Lasso is generally used when we have more number of features, because it automatically does feature selection.

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
score = rmsle_cv(lasso)
print("Lasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %% [markdown]
# # 4. Elastic Net Regression
#
# Elastic net is basically a combination of both L1 and L2 regularization. So if you know elastic net, you can implement both Ridge and Lasso by tuning the parameters.

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %% [markdown]
# # 5. Ridge Regression
# - It shrinks the parameters, therefore it is mostly used to prevent multicollinearity.
# - It reduces the model complexity by coefficient shrinkage.
# - It uses L2 regularization technique.

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))

# %%
# Train the model
XGBoost = xgb_model.fit(train.values, y_train)
LassoMd = lasso.fit(train.values,y_train)
ENetMd = ENet.fit(train.values,y_train)
KRRMd = KRR.fit(train.values,y_train)
GBoostMd = GBoost.fit(train.values,y_train)

# %% [markdown]
# # Mean of all model's prediction.
# np.expm1 ( ) is used to calculate exp(x) - 1 for all elements in the array.

# %%
Lasso_pred = np.expm1(LassoMd.predict(test.values))
XGB_pred = np.expm1(XGBoost.predict(test.values))
ENet_pred = np.expm1(ENetMd.predict(test.values))
KRR_pred = np.expm1(KRRMd.predict(test.values))
GB_pred = np.expm1(GBoost.predict(test.values))

# %%
finalMd = (np.expm1(LassoMd.predict(test.values)) + 
           np.expm1(ENetMd.predict(test.values)) + 
           np.expm1(KRRMd.predict(test.values)) + 
           np.expm1(GBoostMd.predict(test.values)) + 
           np.expm1(XGBoost.predict(test.values)) ) / 5

# %%
finalMd4 = (Lasso_pred + ENet_pred + KRR_pred + GB_pred) / 4

# %% [markdown]
# # Submission

# %%
# For Lasso
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': Lasso_pred})
my_submission.to_csv('Lasso_submission.csv',index=False)

# Score: 0.12181

# %%
# For XGB
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': XGB_pred})
my_submission.to_csv('XGB_submission.csv',index=False)

# Score: 0.11544 (Top 10%)

# %%
# For ENet
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': ENet_pred})
my_submission.to_csv('ENet_submission.csv',index=False)

# Score: 0.12175

# %%
# For KRR
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': KRR_pred})
my_submission.to_csv('KRR_submission.csv',index=False)

# Score: 0.14120

# %%
# For Gboost
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': GB_pred})
my_submission.to_csv('GB_submission.csv',index=False)

# Score: 0.11947

# %%
# Ensemble Result (only 4)
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': finalMd4})
my_submission.to_csv('EnsembleNEW_submission.csv',index=False)
# Score: 0.12036

# %%
# Ensemble Result (Five Features)
my_submission=pd.DataFrame({'ID': test_ID, 'SalePrice': finalMd})
my_submission.to_csv('Ensemble_submission.csv',index=False)
# Score: 0.11945
# Score: 0.11544
